# %% [markdown]
# <a href="https://colab.research.google.com/github/chsrinidh-rao/Ai-Assistant-coding/blob/main/AI_LAB_9_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBLEM--1

# %% [markdown]
# # Task
# Implement the `find_max` Python function three times, each with a different documentation style: standard docstring, inline comments, and Google-style docstring. Then, compare these three documentation styles, detailing their advantages, disadvantages, and suitable use cases. Finally, recommend the best documentation style for a mathematical utilities library with justification.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining a Python function `find_max` with a standard docstring and testing it with examples. This code block will implement the function, its docstring, and demonstrate its usage.

# %%
def find_max(numbers):
    """
    Finds the maximum number in a list of numbers.

    Args:
        numbers (list): A list of numerical values.

    Returns:
        float or int: The largest number in the list.
    """
    if not numbers:
        raise ValueError("The input list cannot be empty.")
    return max(numbers)

# Test the function with example lists
example_list_1 = [10, 5, 20, 15, 30]
result_1 = find_max(example_list_1)
print(f"The maximum number in {example_list_1} is: {result_1}")

example_list_2 = [-1, -5, -2, -8]
result_2 = find_max(example_list_2)
print(f"The maximum number in {example_list_2} is: {result_2}")

example_list_3 = [7]
result_3 = find_max(example_list_3)
print(f"The maximum number in {example_list_3} is: {result_3}")
# Out:
# The maximum number in [10, 5, 20, 15, 30] is: 30
# The maximum number in [-1, -5, -2, -8] is: -1
# The maximum number in [7] is: 7

# %% [markdown]
# **Reasoning**:
# The subtask requires redefining the `find_max` function with inline comments and testing it. This code block will implement the function with inline comments and demonstrate its usage with the given example lists.

# %%
def find_max(numbers):
    # This function finds the maximum number in a list of numerical values.

    # Check if the input list is empty
    if not numbers:
        # If the list is empty, raise a ValueError as there's no maximum to find
        raise ValueError("The input list cannot be empty.")
    # Use the built-in max() function to find the largest number in the list
    return max(numbers)

# Test the function with example lists
# Example list 1: positive integers
result_1_inline = find_max(example_list_1)
print(f"The maximum number in {example_list_1} is: {result_1_inline} (Inline Comments)")

# Example list 2: negative integers
result_2_inline = find_max(example_list_2)
print(f"The maximum number in {example_list_2} is: {result_2_inline} (Inline Comments)")

# Example list 3: a single element list
result_3_inline = find_max(example_list_3)
print(f"The maximum number in {example_list_3} is: {result_3_inline} (Inline Comments)")
# Out:
# The maximum number in [10, 5, 20, 15, 30] is: 30 (Inline Comments)
# The maximum number in [-1, -5, -2, -8] is: -1 (Inline Comments)
# The maximum number in [7] is: 7 (Inline Comments)

# %% [markdown]
# **Reasoning**:
# The subtask requires redefining the `find_max` function with a Google-style docstring and testing it. This code block will implement the function with the specified docstring and demonstrate its usage with the given example lists.

# %%
def find_max(numbers):
    """
    Finds the maximum number in a list of numbers.

    This function takes a list of numerical values and returns the largest number within it.
    It handles the case of an empty list by raising a ValueError.

    Args:
        numbers (list): A list of numerical values (int or float).

    Returns:
        int or float: The largest number in the input list.

    Raises:
        ValueError: If the input list `numbers` is empty.

    Examples:
        >>> find_max([1, 2, 3])
        3
        >>> find_max([-10, 0, 5])
        5
    """
    if not numbers:
        raise ValueError("The input list cannot be empty.")
    return max(numbers)

# Test the function with example lists
result_1_google = find_max(example_list_1)
print(f"The maximum number in {example_list_1} is: {result_1_google} (Google-style Docstring)")

result_2_google = find_max(example_list_2)
print(f"The maximum number in {example_list_2} is: {result_2_google} (Google-style Docstring)")

result_3_google = find_max(example_list_3)
print(f"The maximum number in {example_list_3} is: {result_3_google} (Google-style Docstring)")

# Test with an empty list to demonstrate error handling
try:
    find_max([])
except ValueError as e:
    print(f"Successfully caught expected error for empty list: {e}")
# Out:
# The maximum number in [10, 5, 20, 15, 30] is: 30 (Google-style Docstring)
# The maximum number in [-1, -5, -2, -8] is: -1 (Google-style Docstring)
# The maximum number in [7] is: 7 (Google-style Docstring)
# Successfully caught expected error for empty list: The input list cannot be empty.

# %% [markdown]
# #Problem 2: Consider the following Python function:

# %% [markdown]
# ## Define and Document Function (Standard Docstring)
#
# ### Subtask:
# Define the `login` Python function and add a standard Python docstring to it, explaining its purpose, arguments, and return value. Include basic test cases.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining a `login` Python function with a standard docstring and including basic test cases. This code block will implement the function, its docstring, and demonstrate its functionality with example calls.

# %%
def login(username, password):
    """
    Authenticates a user based on provided username and password.

    Args:
        username (str): The username for authentication.
        password (str): The password for authentication.

    Returns:
        bool: True if authentication is successful, False otherwise.
    """
    return username == 'user' and password == 'pass'

# Test cases
print(f"Login with 'user', 'pass': {login('user', 'pass')}") # Expected: True
print(f"Login with 'user', 'wrong': {login('user', 'wrong')}") # Expected: False
print(f"Login with 'admin', 'pass': {login('admin', 'pass')}") # Expected: False
print(f"Login with 'wrong', 'wrong': {login('wrong', 'wrong')}") # Expected: False
# Out:
# Login with 'user', 'pass': True
# Login with 'user', 'wrong': False
# Login with 'admin', 'pass': False
# Login with 'wrong', 'wrong': False

# %% [markdown]
# **Reasoning**:
# The subtask requires defining the `login` function with inline comments and including basic test cases. This code block will implement the function with inline comments and demonstrate its functionality with example calls.

# %%
def login(username, password):
    # This function attempts to authenticate a user by checking their username and password.
    # It takes two string arguments: 'username' and 'password'.

    # Define the expected valid credentials for authentication.
    # For this example, 'user' is the valid username and 'pass' is the valid password.
    valid_username = 'user'
    valid_password = 'pass'

    # Compare the provided username and password with the valid credentials.
    # If both match, the login is successful and True is returned.
    # Otherwise, the login fails and False is returned.
    if username == valid_username and password == valid_password:
        return True # Authentication successful
    else:
        return False # Authentication failed

# Test cases to demonstrate the function's behavior:

# Test 1: Valid credentials (Expected: True)
print(f"Login with 'user', 'pass': {login('user', 'pass')}")

# Test 2: Correct username, incorrect password (Expected: False)
print(f"Login with 'user', 'wrong': {login('user', 'wrong')}")

# Test 3: Incorrect username, correct password (Expected: False)
print(f"Login with 'admin', 'pass': {login('admin', 'pass')}")

# Test 4: Incorrect username, incorrect password (Expected: False)
print(f"Login with 'wrong', 'wrong': {login('wrong', 'wrong')}")
# Out:
# Login with 'user', 'pass': True
# Login with 'user', 'wrong': False
# Login with 'admin', 'pass': False
# Login with 'wrong', 'wrong': False

# %% [markdown]
# **Reasoning**:
# The subtask requires redefining the `login` Python function with a Google-style docstring and including basic test cases. This code block will implement the function with the specified docstring and demonstrate its functionality with example calls.

# %%
def login(username, password):
    """
    Authenticates a user based on provided username and password.

    This function simulates a login process by checking if the given username
    is 'user' and the password is 'pass'.

    Args:
        username (str): The username provided by the user.
        password (str): The password provided by the user.

    Returns:
        bool: True if authentication is successful (username is 'user' and password is 'pass'),
              False otherwise.

    Examples:
        >>> login('user', 'pass')
        True
        >>> login('user', 'wrong_pass')
        False
    """
    # For this example, a simple hardcoded check is used.
    # In a real application, this would involve database lookups and secure password hashing.
    if username == 'user' and password == 'pass':
        return True
    else:
        return False

# Test cases to verify functionality with Google-style docstring:
print(f"Login (Google-style) with 'user', 'pass': {login('user', 'pass')}")        # Expected: True
print(f"Login (Google-style) with 'user', 'wrong': {login('user', 'wrong')}")      # Expected: False
print(f"Login (Google-style) with 'admin', 'pass': {login('admin', 'pass')}")      # Expected: False
print(f"Login (Google-style) with 'wrong', 'wrong': {login('wrong', 'wrong')}")    # Expected: False
# Out:
# Login (Google-style) with 'user', 'pass': True
# Login (Google-style) with 'user', 'wrong': False
# Login (Google-style) with 'admin', 'pass': False
# Login (Google-style) with 'wrong', 'wrong': False

# %% [markdown]
# #Problem 3: Calculator (Automatic Documentation Generation)

# %% [markdown]
# # Task
# Create the `calculator.py` Python module file with a module-level docstring. Inside this module, implement the `add(a, b)` function, including its proper Python docstring with parameter and return value descriptions.

# %% [markdown]
# **Reasoning**:
# The subtask requires creating the `calculator.py` file with a module-level docstring and the `add` function including its docstring. I will use the `%%writefile` magic command to create and populate the file.

# %%
# %%writefile calculator.py
"""
This module provides basic arithmetic operations.
"""

def add(a, b):
    """
    Adds two numbers and returns their sum.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The sum of a and b.
    """
    return a + b
# Out:
# Writing calculator.py

# %% [markdown]
# ## Add subtract and multiply Functions
#
# ### Subtask:
# Add the `subtract(a, b)` and `multiply(a, b)` functions to the `calculator.py` module, ensuring each has a proper Python docstring with parameter and return value descriptions.

# %% [markdown]
# **Reasoning**:
# The subtask requires adding the `subtract` and `multiply` functions to the `calculator.py` file, each with a proper docstring. I will use `%%writefile -a` to append these functions and their documentation.

# %%
# %%writefile -a calculator.py

def subtract(a, b):
    """
    Subtracts the second number from the first and returns the difference.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The difference of a and b (a - b).
    """
    return a - b

def multiply(a, b):
    """
    Multiplies two numbers and returns their product.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The product of a and b (a * b).
    """
    return a * b
# Out:
# Appending to calculator.py

# %% [markdown]
# ## Add divide Function with Error Handling
#
# ### Subtask:
# Add the `divide(a, b)` function to `calculator.py`. This function must include a proper Python docstring with parameter and return value descriptions, and robust error handling for divide-by-zero scenarios.

# %% [markdown]
# **Reasoning**:
# The subtask requires adding the `divide` function to the `calculator.py` file, including a docstring and error handling for division by zero. I will use `%%writefile -a` to append this function to the module.

# %%
# %%writefile -a calculator.py

def divide(a, b):
    """
    Divides the first number by the second and returns the quotient.

    Args:
        a (int or float): The numerator.
        b (int or float): The denominator.

    Returns:
        int or float: The quotient of a and b (a / b).

    Raises:
        ZeroDivisionError: If the denominator `b` is zero.
    """
    if b == 0:
        raise ZeroDivisionError("Cannot divide by zero.")
    return a / b
# Out:
# Appending to calculator.py

# %% [markdown]
# ## Demonstrate Built-in Documentation (help() function)
#
# ### Subtask:
# Show how to use Python's built-in `help()` function to display the module-level documentation and individual function documentation for `calculator.py` within the Python interpreter.

# %% [markdown]
# **Reasoning**:
# To demonstrate the `help()` function, I will first import the `calculator` module. Then, I will use `help(calculator)` to display the module-level docstring, followed by `help()` for each function within the module to show their individual documentation.

# %%
import calculator

print("\n--- Module-level Documentation ---")
help(calculator)

print("\n--- Documentation for add() ---")
help(calculator.add)

print("\n--- Documentation for subtract() ---")
help(calculator.subtract)

print("\n--- Documentation for multiply() ---")
help(calculator.multiply)

print("\n--- Documentation for divide() ---")
help(calculator.divide)
# Out:
# --- Module-level Documentation ---
# Help on module calculator:
#
# NAME
#     calculator - This module provides basic arithmetic operations.
#
# FUNCTIONS
#     add(a, b)
#         Adds two numbers and returns their sum.
#
#         Args:
#             a (int or float): The first number.
#             b (int or float): The second number.
#
#         Returns:
#             int or float: The sum of a and b.
#
#     divide(a, b)
#         Divides the first number by the second and returns the quotient.
#
#         Args:
#             a (int or float): The numerator.
#             b (int or float): The denominator.
#
#         Returns:
#             int or float: The quotient of a and b (a / b).
#
#         Raises:
#             ZeroDivisionError: If the denominator `b` is zero.
#
#     multiply(a, b)
#         Multiplies two numbers and returns their product.
#
#         Args:
#             a (int or float): The first number.
#             b (int or float): The second number.
#
# ...

# %% [markdown]
# **Reasoning**:
# Now I will demonstrate how to use the `pydoc` utility to view the module-level documentation for `calculator.py`.

# %%
print("--- pydoc output for module 'calculator' ---")
# !pydoc calculator
# Out:
# --- pydoc output for module 'calculator' ---
# /bin/bash: line 1: pydoc: command not found

# %% [markdown]
# **Reasoning**:
# The previous attempt to use `!pydoc` failed because the command was not found. I will try invoking `pydoc` as a Python module using `!python -m pydoc` which is a more robust way to access it in environments like Colab.

# %%
print("--- pydoc output for module 'calculator' ---")
# !python -m pydoc calculator
# Out:
# --- pydoc output for module 'calculator' ---
# Help on module calculator:
#
# E
#     calculator - This module provides basic arithmetic operations.
#
# S
# d(a, b)
#         Adds two numbers and returns their sum.
#
#         Args:
#             a (int or float): The first number.
#             b (int or float): The second number.
#
#         Returns:
#             int or float: The sum of a and b.
#
# e(a, b)
#         Divides the first number by the second and returns the quotient.
#
#         Args:
#             a (int or float): The numerator.
#             b (int or float): The denominator.
#
#         Returns:
#             int or float: The quotient of a and b (a / b).
#
#         Raises:
#             ZeroDivisionError: If the denominator `b` is zero.
#
# y(a, b)
#         Multiplies two numbers and returns their product.
#
#         Args:
#             a (int or float): The first number.
#             b (int or float): The second number.
#
#         Returns:
# ...

# %% [markdown]
# **Reasoning**:
# Now I will demonstrate how to use `pydoc` to view the documentation for the `add` function within the `calculator` module.

# %%
print("--- pydoc output for function 'calculator.add' ---")
# !python -m pydoc calculator.add
# Out:
# --- pydoc output for function 'calculator.add' ---
# Help on function add in calculator:
#
# d = add(a, b)
#     Adds two numbers and returns their sum.
#
#     Args:
#         a (int or float): The first number.
#         b (int or float): The second number.
#
#     Returns:
#         int or float: The sum of a and b.

# %% [markdown]
# **Reasoning**:
# Next, I will demonstrate how to use `pydoc` to view the documentation for the `subtract` function within the `calculator` module, following the instructions.

# %%
print("-- pydoc output for function 'calculator.subtract' ---")
# !python -m pydoc calculator.subtract
# Out:
# -- pydoc output for function 'calculator.subtract' ---
# Help on function subtract in calculator:
#
# t = subtract(a, b)
#     Subtracts the second number from the first and returns the difference.
#
#     Args:
#         a (int or float): The first number.
#         b (int or float): The second number.
#
#     Returns:
#         int or float: The difference of a and b (a - b).

# %% [markdown]
# **Reasoning**:
# Now I will demonstrate how to use `pydoc` to view the documentation for the `multiply` function within the `calculator` module, following the instructions.

# %%
print("--- pydoc output for function 'calculator.multiply' ---")
# !python -m pydoc calculator.multiply
# Out:
# --- pydoc output for function 'calculator.multiply' ---
# Help on function multiply in calculator:
#
# y = multiply(a, b)
#     Multiplies two numbers and returns their product.
#
#     Args:
#         a (int or float): The first number.
#         b (int or float): The second number.
#
#     Returns:
#         int or float: The product of a and b (a * b).

# %% [markdown]
# **Reasoning**:
# Now I will demonstrate how to use `pydoc` to view the documentation for the `divide` function within the `calculator` module, following the instructions.

# %%
print("--- pydoc output for function 'calculator.divide' ---")
# !python -m pydoc calculator.divide
# Out:
# --- pydoc output for function 'calculator.divide' ---
# Help on function divide in calculator:
#
# e = divide(a, b)
#     Divides the first number by the second and returns the quotient.
#
#     Args:
#         a (int or float): The numerator.
#         b (int or float): The denominator.
#
#     Returns:
#         int or float: The quotient of a and b (a / b).
#
#     Raises:
#         ZeroDivisionError: If the denominator `b` is zero.

# %% [markdown]
# **Reasoning**:
# I will execute the `pydoc -w` command as a Python module to generate the `calculator.html` documentation file.

# %%
print("Generating HTML documentation for calculator.py...")
# !python -m pydoc -w calculator
# Out:
# Generating HTML documentation for calculator.py...
# wrote calculator.html

# %% [markdown]
# #Problem 4: Conversion Utilities Module

# %% [markdown]
# **Reasoning**:
# The subtask requires creating the `calculator.py` file with a module-level docstring and the `add` function including its docstring. I will use the `%%writefile` magic command to create and populate the file.

# %%
# %%writefile calculator.py
"""
This module provides basic arithmetic operations.
"""

def add(a, b):
    """
    Adds two numbers and returns their sum.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The sum of a and b.
    """
    return a + b
# Out:
# Overwriting calculator.py

# %% [markdown]
# **Reasoning**:
# The subtask requires adding the `subtract` and `multiply` functions to the `calculator.py` file, each with a proper docstring. I will use `%%writefile -a` to append these functions and their documentation.

# %%
# %%writefile -a calculator.py

def subtract(a, b):
    """
    Subtracts the second number from the first and returns the difference.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The difference of a and b (a - b).
    """
    return a - b

def multiply(a, b):
    """
    Multiplies two numbers and returns their product.

    Args:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The product of a and b (a * b).
    """
    return a * b
# Out:
# Appending to calculator.py

# %% [markdown]
# **Reasoning**:
# As instructed in the previous markdown block, I will now run `!ls` to verify that the `calculator.html` file was successfully generated and exists in the current directory.

# %%
print("Verifying file creation with `!ls`:")
# !ls
# Out:
# Verifying file creation with `!ls`:
# calculator.html  calculator.py	__pycache__  sample_data

# %% [markdown]
# #Problem 5 – Course Management Module

# %%
# %%writefile course.py
"""
This module manages course information.
"""

_courses = {}

def add_course(course_id, name, credits):
    """
    Adds a new course to the course management system.

    Args:
        course_id (str): The unique identifier for the course.
        name (str): The name of the course.
        credits (int): The number of credits for the course.

    Returns:
        dict: A dictionary containing the details of the newly added course.
    """
    course_details = {
        "name": name,
        "credits": credits
    }
    _courses[course_id] = course_details
    return {course_id: course_details}
# Out:
# Writing course.py

# %% [markdown]
# **Reasoning**:
# The subtask now requires demonstrating the `add_course` function's functionality by importing the `course` module and calling `add_course` with example data, then printing the `_courses` dictionary to show the added course.

# %%
import course

print("Adding course 'CS101'...")
added_course_info = course.add_course("CS101", "Introduction to Computer Science", 3)
print(f"Returned by add_course: {added_course_info}")
print(f"Current courses in module (after adding CS101): {course._courses}")

print("\nAdding course 'MA201'...")
added_course_info_2 = course.add_course("MA201", "Calculus I", 4)
print(f"Returned by add_course: {added_course_info_2}")
print(f"Current courses in module (after adding MA201): {course._courses}")
# Out:
# Adding course 'CS101'...
# Returned by add_course: {'CS101': {'name': 'Introduction to Computer Science', 'credits': 3}}
# Current courses in module (after adding CS101): {'CS101': {'name': 'Introduction to Computer Science', 'credits': 3}}
#
# Adding course 'MA201'...
# Returned by add_course: {'MA201': {'name': 'Calculus I', 'credits': 4}}
# Current courses in module (after adding MA201): {'CS101': {'name': 'Introduction to Computer Science', 'credits': 3}, 'MA201': {'name': 'Calculus I', 'credits': 4}}

# %% [markdown]
# **Reasoning**:
# The subtask requires adding the `get_course_details` function to the `course.py` module, including its docstring. I will use `%%writefile -a` to append this function to the file.

# %%
# %%writefile -a course.py

def get_course_details(course_id):
    """
    Retrieves the details of a specific course.

    Args:
        course_id (str): The unique identifier for the course.

    Returns:
        dict or None: A dictionary containing the course's name and credits if found,
                      otherwise None.
    """
    return _courses.get(course_id)
# Out:
# Appending to course.py

# %% [markdown]
# **Reasoning**:
# The subtask requires demonstrating the functionality of the `get_course_details` function. To do this, I need to reload the `course` module and then call `get_course_details` with both existing and non-existing course IDs to verify its behavior.

# %%
import importlib
import course

# Reload the module to include the newly added function
importlib.reload(course)

print("\n--- Testing get_course_details ---")

# Test with an existing course
existing_course_id = "CS101"
cs101_details = course.get_course_details(existing_course_id)
print(f"Details for {existing_course_id}: {cs101_details}")

# Test with another existing course
existing_course_id_2 = "MA201"
ma201_details = course.get_course_details(existing_course_id_2)
print(f"Details for {existing_course_id_2}: {ma201_details}")

# Test with a non-existent course
non_existent_course_id = "PH301"
ph301_details = course.get_course_details(non_existent_course_id)
print(f"Details for {non_existent_course_id}: {ph301_details}")
# Out:
# --- Testing get_course_details ---
# Details for CS101: None
# Details for MA201: None
# Details for PH301: None

# %% [markdown]
# **Reasoning**:
# The previous execution of `get_course_details` returned `None` for existing courses because reloading the `course` module re-initialized the `_courses` dictionary. To correctly demonstrate `get_course_details`, I need to re-add the courses after reloading the module and before attempting to retrieve their details.

# %%
import importlib
import course

# Reload the module to include the newly added function AND reset the _courses dictionary
importlib.reload(course)

# Re-add courses to populate the _courses dictionary after reload
print("\n--- Re-adding courses after module reload ---")
_ = course.add_course("CS101", "Introduction to Computer Science", 3)
_ = course.add_course("MA201", "Calculus I", 4)
print(f"Current courses in module after re-adding: {course._courses}")

print("\n--- Testing get_course_details ---")

# Test with an existing course
existing_course_id = "CS101"
cs101_details = course.get_course_details(existing_course_id)
print(f"Details for {existing_course_id}: {cs101_details}")

# Test with another existing course
existing_course_id_2 = "MA201"
ma201_details = course.get_course_details(existing_course_id_2)
print(f"Details for {existing_course_id_2}: {ma201_details}")

# Test with a non-existent course
non_existent_course_id = "PH301"
ph301_details = course.get_course_details(non_existent_course_id)
print(f"Details for {non_existent_course_id}: {ph301_details}")
# Out:
# --- Re-adding courses after module reload ---
# Current courses in module after re-adding: {'CS101': {'name': 'Introduction to Computer Science', 'credits': 3}, 'MA201': {'name': 'Calculus I', 'credits': 4}}
#
# --- Testing get_course_details ---
# Details for CS101: {'name': 'Introduction to Computer Science', 'credits': 3}
# Details for MA201: {'name': 'Calculus I', 'credits': 4}
# Details for PH301: None

# %% [markdown]
# ## Implement remove_course function
#
# ### Subtask:
# Add the `remove_course(course_id)` function to `course.py`. Include a docstring, parameter description, and return value description. Add error handling for cases where the course is not found.

# %% [markdown]
# **Reasoning**:
# The subtask requires adding the `remove_course` function to the `course.py` file with a proper docstring and error handling. I will use `%%writefile -a` to append this function to the module.

# %%
# %%writefile -a course.py

def remove_course(course_id):
    """
    Removes a course from the course management system.

    Args:
        course_id (str): The unique identifier for the course to be removed.

    Returns:
        bool: True if the course was successfully removed, False otherwise (e.g., if not found).
    """
    if course_id in _courses:
        del _courses[course_id]
        return True
    return False
# Out:
# Appending to course.py

# %% [markdown]
# **Reasoning**:
# The subtask requires demonstrating the `remove_course` function. This involves reloading the `course` module, re-populating the `_courses` dictionary (as reloading clears it), and then testing `remove_course` with both an existing and a non-existent course ID to verify its behavior.

# %%
import importlib
import course

# Reload the module to include the newly added function and reset the _courses dictionary
importlib.reload(course)

# Re-add courses to populate the _courses dictionary after reload
print("\n--- Re-adding courses after module reload ---")
_ = course.add_course("CS101", "Introduction to Computer Science", 3)
_ = course.add_course("MA201", "Calculus I", 4)
print(f"Current courses in module after re-adding: {course._courses}")

print("\n--- Testing remove_course ---")

# Test with an existing course
existing_course_to_remove = "CS101"
removal_success = course.remove_course(existing_course_to_remove)
print(f"Attempting to remove '{existing_course_to_remove}': {removal_success}")
print(f"Current courses in module: {course._courses}")

# Test with a non-existent course
non_existent_course_to_remove = "PH301"
removal_failure = course.remove_course(non_existent_course_to_remove)
print(f"Attempting to remove '{non_existent_course_to_remove}': {removal_failure}")
print(f"Current courses in module: {course._courses}")

# Test removing the other existing course
existing_course_to_remove_2 = "MA201"
removal_success_2 = course.remove_course(existing_course_to_remove_2)
print(f"Attempting to remove '{existing_course_to_remove_2}': {removal_success_2}")
print(f"Current courses in module: {course._courses}")
# Out:
# --- Re-adding courses after module reload ---
# Current courses in module after re-adding: {'CS101': {'name': 'Introduction to Computer Science', 'credits': 3}, 'MA201': {'name': 'Calculus I', 'credits': 4}}
#
# --- Testing remove_course ---
# Attempting to remove 'CS101': True
# Current courses in module: {'MA201': {'name': 'Calculus I', 'credits': 4}}
# Attempting to remove 'PH301': False
# Current courses in module: {'MA201': {'name': 'Calculus I', 'credits': 4}}
# Attempting to remove 'MA201': True
# Current courses in module: {}

# %% [markdown]
# ## Demonstrate help() function
#
# ### Subtask:
# Show how to use Python's built-in `help()` function to display the module-level documentation and individual function documentation for `course.py` within the Python interpreter.

# %% [markdown]
# **Reasoning**:
# To demonstrate the `help()` function for the `course` module and its functions, I need to import the module and then call `help()` on the module itself and on each of its public functions (`add_course`, `get_course_details`, `remove_course`).

# %%
import course

print("\n--- Module-level Documentation for course ---\n")
help(course)

print("\n--- Documentation for add_course() ---\n")
help(course.add_course)

print("\n--- Documentation for get_course_details() ---\n")
help(course.get_course_details)

print("\n--- Documentation for remove_course() ---\n")
help(course.remove_course)
# Out:
# --- Module-level Documentation for course ---
#
# Help on module course:
#
# NAME
#     course - This module manages course information.
#
# FUNCTIONS
#     add_course(course_id, name, credits)
#         Adds a new course to the course management system.
#
#         Args:
#             course_id (str): The unique identifier for the course.
#             name (str): The name of the course.
#             credits (int): The number of credits for the course.
#
#         Returns:
#             dict: A dictionary containing the details of the newly added course.
#
#     get_course_details(course_id)
#         Retrieves the details of a specific course.
#
#         Args:
#             course_id (str): The unique identifier for the course.
#
#         Returns:
#             dict or None: A dictionary containing the course's name and credits if found,
#                           otherwise None.
#
#     remove_course(course_id)
#         Removes a course from the course management system.
#
# ...

# %%
print("--- pydoc output for module 'course' ---")
# !python -m pydoc course
# Out:
# --- pydoc output for module 'course' ---
# Help on module course:
#
# E
#     course - This module manages course information.
#
# S
# e(course_id, name, credits)
#         Adds a new course to the course management system.
#
#         Args:
#             course_id (str): The unique identifier for the course.
#             name (str): The name of the course.
#             credits (int): The number of credits for the course.
#
#         Returns:
#             dict: A dictionary containing the details of the newly added course.
#
# s(course_id)
#         Retrieves the details of a specific course.
#
#         Args:
#             course_id (str): The unique identifier for the course.
#
#         Returns:
#             dict or None: A dictionary containing the course's name and credits if found,
#                           otherwise None.
#
# e(course_id)
#         Removes a course from the course management system.
#
#         Args:
# ...

# %% [markdown]
# **Reasoning**:
# Next, I will use `pydoc` to display the documentation for the `add_course` function, as per the instructions.

# %%
print("--- pydoc output for function 'course.add_course' ---")
# !python -m pydoc course.add_course
# Out:
# --- pydoc output for function 'course.add_course' ---
# Help on function add_course in course:
#
# e = add_course(course_id, name, credits)
#     Adds a new course to the course management system.
#
#     Args:
#         course_id (str): The unique identifier for the course.
#         name (str): The name of the course.
#         credits (int): The number of credits for the course.
#
#     Returns:
#         dict: A dictionary containing the details of the newly added course.

# %% [markdown]
# **Reasoning**:
# Now I will demonstrate how to use `pydoc` to view the documentation for the `get_course_details` function within the `course` module, as per the instructions.

# %%
print("--- pydoc output for function 'course.get_course_details' ---")
# !python -m pydoc course.get_course_details
# Out:
# --- pydoc output for function 'course.get_course_details' ---
# Help on function get_course_details in course:
#
# s = get_course_details(course_id)
#     Retrieves the details of a specific course.
#
#     Args:
#         course_id (str): The unique identifier for the course.
#
#     Returns:
#         dict or None: A dictionary containing the course's name and credits if found,
#                       otherwise None.

# %% [markdown]
# **Reasoning**:
# Finally, I will demonstrate how to use `pydoc` to view the documentation for the `remove_course` function within the `course` module, completing all the instructions for `pydoc`.

# %%
print("--- pydoc output for function 'course.remove_course' ---")
# !python -m pydoc course.remove_course
# Out:
# --- pydoc output for function 'course.remove_course' ---
# Help on function remove_course in course:
#
# e = remove_course(course_id)
#     Removes a course from the course management system.
#
#     Args:
#         course_id (str): The unique identifier for the course to be removed.
#
#     Returns:
#         bool: True if the course was successfully removed, False otherwise (e.g., if not found).

# %% [markdown]
# **Reasoning**:
# I will generate the HTML documentation for the `course.py` module using `pydoc -w` as specified in the instructions.

# %%
print("Generating HTML documentation for course.py...")
# !python -m pydoc -w course
# Out:
# Generating HTML documentation for course.py...
# wrote course.html

# %% [markdown]
# **Reasoning**:
# Next, I will verify that the `course.html` file has been created by listing the contents of the current directory using `!ls`, as specified in the instructions.

# %%
print("Verifying file creation with `!ls`:")
# !ls
# Out:
# Verifying file creation with `!ls`:
# calculator.html  course.html  __pycache__
# calculator.py	 course.py    sample_data
