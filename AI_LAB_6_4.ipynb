# %% [markdown]
# <a href="https://colab.research.google.com/github/chsrinidh-rao/Ai-Assistant-coding/blob/main/AI_LAB_6_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task 1: Student Performance Evaluation System

# %%
class Student:
    def __init__(self, name, roll_number, marks):
        self.name = name
        self.roll_number = roll_number
        self.marks = marks

    def display_details(self):
        print(f"Name: {self.name}, Roll Number: {self.roll_number}, Marks: {self.marks}")

    def check_performance(self, class_average):
        if self.marks > class_average:
            return "Student is performing above average"
        else:
            return "Student is performing below average"

# Example usage:
# Create a student object
student1 = Student("Rajesh", 101, 85)

# Assume class average is 75
avg_marks = 75

# Display student details
student1.display_details()

# Print performance result
print(student1.check_performance(avg_marks))
# Out:
# Name: Rajesh, Roll Number: 101, Marks: 85
# Student is performing above average

# %% [markdown]
# #Task 2: Data Processing in a Monitoring System

# %%
# Sensor readings collected from a monitoring system
sensor_readings = [12, 7, 5, 20, 9, 14, 3, 8]

# Write a for loop to iterate over the sensor readings
for reading in sensor_readings:
    # Check if the reading is an even number using modulus operator
    if reading % 2 == 0:
        # Calculate the square of the reading
        square = reading ** 2
        # Print the result in the specified format
        print(f"Even reading: {reading}, Square: {square}")
# Out:
# Even reading: 12, Square: 144
# Even reading: 20, Square: 400
# Even reading: 14, Square: 196
# Even reading: 8, Square: 64

# %% [markdown]
# #Task 3: Banking Transaction Simulation

# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposit successful. New balance for {self.account_holder}: ${self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawal successful. New balance for {self.account_holder}: ${self.balance}")
        else:
            print("Insufficient balance. Withdrawal not allowed.")

# Example usage
account = BankAccount("Rajesh", 5000)

account.deposit(2000)
account.withdraw(3000)
account.withdraw(5000)
# Out:
# Deposit successful. New balance for Rajesh: $7000
# Withdrawal successful. New balance for Rajesh: $4000
# Insufficient balance. Withdrawal not allowed.

# %% [markdown]
# #Task 4: Student Scholarship Eligibility Check

# %%
# List of students with their scores
students = [
    {"name": "Rajesh", "score": 82},
    {"name": "Ananya", "score": 74},
    {"name": "Kiran", "score": 90},
    {"name": "Sneha", "score": 68},
    {"name": "Vikram", "score": 78}
]

# Initialize index for while loop
index = 0

# Use a while loop to iterate through the students list
while index < len(students):
    student = students[index]
    # Check if student score is greater than 75
    if student["score"] > 75:
        # Print the student's name in a readable format
        print(f"{student['name']} is eligible for scholarship with a score of {student['score']}.")
    # Increment the index properly to avoid infinite loop
    index += 1
# Out:
# Rajesh is eligible for scholarship with a score of 82.
# Kiran is eligible for scholarship with a score of 90.
# Vikram is eligible for scholarship with a score of 78.

# %% [markdown]
# #Task 5: Online Shopping Cart Module

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, name, price, quantity):
        item = {"name": name, "price": price, "quantity": quantity}
        self.items.append(item)
        print(f"Added {quantity} x {name} to the cart.")

    def remove_item(self, name):
        found = False
        for item in self.items:
            if item["name"] == name:
                self.items.remove(item)
                found = True
                print(f"Removed {name} from the cart.")
                break
        if not found:
            print(f"{name} not found in the cart.")

    def calculate_total(self):
        total = 0
        for item in self.items:
            total += item["price"] * item["quantity"]

        if total > 5000:
            discount = total * 0.10
            final_amount = total - discount
            print(f"Total before discount: ${total}. Applied 10% discount: ${discount:.2f}")
        else:
            final_amount = total

        return final_amount

# Example usage
cart = ShoppingCart()

cart.add_item("Laptop", 45000, 1)
cart.add_item("Mouse", 500, 2)
cart.add_item("Keyboard", 1500, 1)

cart.remove_item("Mouse")

final_amount = cart.calculate_total()
print("Final Amount to Pay:", final_amount)
# Out:
# Added 1 x Laptop to the cart.
# Added 2 x Mouse to the cart.
# Added 1 x Keyboard to the cart.
# Removed Mouse from the cart.
# Total before discount: $46500. Applied 10% discount: $4650.00
# Final Amount to Pay: 41850.0
